# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# ![image.png](attachment:35f02d61-661b-4220-9695-a1d3c28a5f3c.png)

# %%
sem = 0.73 / math.sqrt(130)
sem
# Out:
# 0.06402523540941313

# %%
upper_lim = 98.25 + sem
lower_lim = 98.25 - sem
lower_lim, upper_lim
# Out:
# (98.18597476459058, 98.31402523540942)

# %% [markdown]
# ![image.png](attachment:42e95e86-28b0-4188-bb3e-dd9b1b233c47.png)

# %%
sem = 3.1 / math.sqrt(500)
sem
# Out:
# 0.13863621460498696

# %%
upper_lim = 5.4 + sem
lower_lim = 5.4 - sem
lower_lim, upper_lim
# Out:
# (5.261363785395013, 5.5386362146049875)

# %%
2.5 / math.sqrt(40)
# Out:
# 0.3952847075210474

# %% [markdown]
# ![image.png](attachment:37a6a9ac-f323-4bf4-8f25-85adf52892a7.png)

# %%
# H0: this company does not pay substandard wages
# Ha: this company pays substandard wages

x_bar = 12.50 # sample mean
n = 40 # number of samples
sigma = 2.50 # sd of population
mu = 13.50 # Population mean

# %%
z = (x_bar - mu)/(sigma/math.sqrt(n))
z
# Out:
# -2.5298221281347035

# %%
p_value = stats.norm.cdf(z)
p_value
# Out:
# 0.005706018193000824

# %%
alpha = 0.01

if p_value<alpha:
    print('At {} level of significance, we can reject the null hypothesis in favor of alternative hypothesis.'.format(alpha))
else:
    print('At {} level of significance, we fail to reject the null hypothesis.'.format(alpha))
# Out:
# At 0.01 level of significance, we can reject the null hypothesis in favor of alternative hypothesis.

# %% [markdown]
# ![image.png](attachment:21830bbb-bfe9-4217-aea8-a1e7e44c65d0.png)

# %%
soil = pd.read_excel("soil.xlsx")
soil1 = soil["Soil1"]
soil1.dropna(inplace=True)
soil2 = soil["Soil2"]

# %%
levene_test = stats.levene(soil1, soil2)
levene_test  # equal variances assumed
# Out:
# LeveneResult(statistic=0.31486292982090475, pvalue=0.5767018253541134)

# %%
ind_test = stats.ttest_ind(soil1, soil2, equal_var=True)
ind_test
# Out:
# TtestResult(statistic=5.1681473319343345, pvalue=2.59322873235282e-06, df=63.0)

# %%
ind_test.pvalue < 0.01
# True. So, we have sufficient evidence to indicate that soils appear to differ 
# with respect to average shear strength
# Out:
# True
